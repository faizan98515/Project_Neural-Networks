# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import cifar10

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
print('CIFAR-10 Dataset: ', X_train.shape, y_train.shape, X_test.shape, y_test.shape)

# Normalize pixel values from [0,255] to [0,1]
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

print('After reshpaing: ', X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# CIFAR-10 Dataset:  (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)
# After reshpaing:  (50000, 32, 32, 3) (50000, 10) (10000, 32, 32, 3) (10000, 10)

# %%
model2 = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3), padding='same'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(16, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(16, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(256, activation='relu'),
    Dense(10, activation='softmax')
])

model2.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 16, 16, 16)          │           4,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 8, 8, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 8, 8, 16)            │           2,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 4, 4, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 76,202 (297.66 KB)
#  Trainable params: 76,202 (297.66 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model2.compile(
    optimizer=Adam(learning_rate=0.001),
    loss=CategoricalCrossentropy(),
    metrics=['accuracy']
)

# %%
history = model2.fit(
    X_train, y_train,
    validation_split=0.2,  # 20% of training data for validation
    epochs=20,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 57s 44ms/step - accuracy: 0.3434 - loss: 1.7859 - val_accuracy: 0.5085 - val_loss: 1.3592
# Epoch 2/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 54s 43ms/step - accuracy: 0.5240 - loss: 1.3223 - val_accuracy: 0.5870 - val_loss: 1.1843
# Epoch 3/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 43ms/step - accuracy: 0.5872 - loss: 1.1517 - val_accuracy: 0.5727 - val_loss: 1.1922
# Epoch 4/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 83s 44ms/step - accuracy: 0.6258 - loss: 1.0485 - val_accuracy: 0.6333 - val_loss: 1.0476
# Epoch 5/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 80s 43ms/step - accuracy: 0.6576 - loss: 0.9558 - val_accuracy: 0.6435 - val_loss: 1.0039
# Epoch 6/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 43ms/step - accuracy: 0.6836 - loss: 0.8870 - val_accuracy: 0.6522 - val_loss: 1.0029
# Epoch 7/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 83s 43ms/step - accuracy: 0.7017 - loss: 0.8446 - val_accuracy: 0.6526 - val_loss: 0.9912
# Epoch 8/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 43ms/step - accuracy: 0.7225 - loss: 0.7889 - val_accuracy: 0.6804 - val_loss: 0.9296
# Epoch 9/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 83s 44ms/step - accuracy: 0.7399 - loss: 0.7385 - val_accuracy: 0.6841 - val_loss: 0.9333
# Epoch 10/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 83s 44ms/step - accuracy: 0.7545 - loss: 0.6996 - val_accuracy: 0.6857 - val_loss: 0.9385
# Epoch 11/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 80s 43ms/step - accuracy: 0.7672 - loss: 0.6552 - val_accuracy: 0.6841 - val_loss: 0.9413
# Epoch 12/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 82s 43ms/step - accuracy: 0.7853 - loss: 0.6121 - val_accuracy: 0.6924 - val_loss: 0.9295
# Epoch 13/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 56s 45ms/step - accuracy: 0.7951 - loss: 0.5742 - val_accuracy: 0.6926 - val_loss: 0.9373
# Epoch 14/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 54s 43ms/step - accuracy: 0.8024 - loss: 0.5577 - val_accuracy: 0.6891 - val_loss: 0.9677
# Epoch 15/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 54s 43ms/step - accuracy: 0.8144 - loss: 0.5323 - val_accuracy: 0.6909 - val_loss: 1.0160
# Epoch 16/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 54s 43ms/step - accuracy: 0.8218 - loss: 0.5017 - val_accuracy: 0.6878 - val_loss: 1.0508
# Epoch 17/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 84s 44ms/step - accuracy: 0.8296 - loss: 0.4781 - val_accuracy: 0.6926 - val_loss: 1.0189
# Epoch 18/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 52s 42ms/step - accuracy: 0.8418 - loss: 0.4421 - val_accuracy: 0.6932 - val_loss: 1.0379
# Epoch 19/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.8531 - loss: 0.4113 - val_accuracy: 0.6905 - val_loss: 1.0528
# Epoch 20/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 54s 43ms/step - accuracy: 0.8644 - loss: 0.3934 - val_accuracy: 0.6865 - val_loss: 1.1174

# %%
loss, accuracy = model2.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")
# Out:
# Test Loss: 2.2781, Test Accuracy: 0.6617

# %%
import numpy as np
X_sample = X_test[0:1]
y_sample_true = np.argmax(y_test[0])
y_pred = model2.predict(X_sample)
y_pred_label = np.argmax(y_pred[0])
print(f"Predicted Label: {y_pred_label}, True Label: {y_sample_true}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Predicted Label: 5, True Label: 3
